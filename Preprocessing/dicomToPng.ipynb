# %%
import pandas as pd
import numpy as np
import os
import pydicom
from tqdm import tqdm
from skimage.io import imsave

# %% [markdown]
# Load Duke_Names xlsx

# %%
df = pd.read_excel('Duke_Names.xlsx')
print(df)
# Out:
#              Mri Id        Patient Id  Start Row  End Row  Start Column  \
# 0    Breast_MRI_001  Duke_Patient_001        234      271           308
# 1    Breast_MRI_002  Duke_Patient_002        251      294           108
# 2    Breast_MRI_003  Duke_Patient_003        351      412            82
# 3    Breast_MRI_004  Duke_Patient_004        262      280           193
# 4    Breast_MRI_005  Duke_Patient_005        188      213           138
# ..              ...               ...        ...      ...           ...
# 345  Breast_MRI_346  Duke_Patient_346        265      357           310
# 346  Breast_MRI_347  Duke_Patient_347        272      294           353
# 347  Breast_MRI_348  Duke_Patient_348        264      279           383
# 348  Breast_MRI_349  Duke_Patient_349        385      423           138
# 349  Breast_MRI_350  Duke_Patient_350        380      448           118
#
#      End Column  Start Slice  End Slice Patient Name
# ...

# %% [markdown]
# Load a nii file just to check

# %%
nii_image = pydicom.dcmread('./DataNiiFormat/pat001.nii')
# Out:
# ---------------------------------------------------------------------------
# InvalidDicomError                         Traceback (most recent call last)
# c:\Users\aimilios.potoupnis\Projects\NTUA-Diploma-Thesis\dicomToPng.ipynb Cell 5 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/aimilios.potoupnis/Projects/NTUA-Diploma-Thesis/dicomToPng.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> nii_image = pydicom.dcmread('./DataNiiFormat/pat001.nii')
#
# File c:\Users\aimilios.potoupnis\AppData\Local\anaconda3\envs\diploma-thesis-ntua\lib\site-packages\pydicom\filereader.py:1030, in dcmread(fp, defer_size, stop_before_pixels, force, specific_tags)
#    1028     stop_when = _at_pixel_data
#    1029 try:
# -> 1030     dataset = read_partial(
#    1031         fp,
#    1032         stop_when,
#    1033         defer_size=size_in_bytes(defer_size),
#    1034         force=force,
#    1035         specific_tags=specific_tags,
#    1036     )
#    1037 finally:
# ...
